# %% [markdown]
# <a href="https://colab.research.google.com/github/Ervicc/cs1-python-Diamond-Cansancio/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Grade 7!")
# Out:
# Hello Grade 7!
